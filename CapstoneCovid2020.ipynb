# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/content/drive/MyDrive/gigih 2.0/Covid Cases in Indonesia - Covid Cases in Indonesia.csv')
data.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (40,41,43,44,45,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  03/01/2020             ID-JK  DKI Jakarta          2           0
# 1  03/02/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
#
#    Total Recovered  ...  region_id Unnamed: 39  Province.1  \
# 0               41  ...        DJA         NaN        Aceh
# 1               41  ...        DJA         NaN        Bali
#
#   Province (Data BPS) Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45  \
# 0                Aceh         1.0        Aceh         NaN         NaN
# ...

# %%
data.shape
# Out:
# (21759, 48)

# %%
df=data[['Date','Province','Total Cases','Total Deaths','Total Recovered','Island','Total Districts','Total Urban Villages','Total Rural Villages','Population','Case Fatality Rate','Case Recovered Rate']]
df.head(10)
# Out:
#          Date     Province  Total Cases  Total Deaths  Total Recovered  \
# 0  03/01/2020  DKI Jakarta           39            20               41
# 1  03/02/2020  DKI Jakarta           41            20               41
# 2  03/02/2020          NaN            2             0                0
# 3  03/02/2020         Riau            2             0                3
# 4  03/03/2020  DKI Jakarta           43            20               41
# 5  03/03/2020          NaN            2             0                0
# 6  03/03/2020   Jawa Barat            1             1                8
# 7  03/03/2020         Riau            2             0                3
# 8  03/04/2020  DKI Jakarta           45            20               41
# 9  03/04/2020          NaN            2             0                0
#
#      Island  Total Districts  Total Urban Villages  Total Rural Villages  \
# 0      Jawa               44                 267.0                   NaN
# ...

# %%
df1=df["Province"].unique()
df1.shape
#f1
# Out:
# (35,)

# %% [markdown]
# ## remove province that has null value

# %%
new=df.dropna(subset=["Province"])
new["Province"].unique()
# Out:
# array(['DKI Jakarta', 'Riau', 'Jawa Barat', 'Banten', 'Jawa Tengah',
#        'Sulawesi Tenggara', 'Bali', 'Kalimantan Timur',
#        'Daerah Istimewa Yogyakarta', 'Sumatera Utara', 'Jawa Timur',
#        'Kepulauan Riau', 'Sulawesi Selatan', 'Jambi', 'Maluku', 'Papua',
#        'Maluku Utara', 'Sumatera Selatan', 'Aceh', 'Kalimantan Tengah',
#        'Lampung', 'Sulawesi Tengah', 'Sulawesi Utara', 'Sumatera Barat',
#        'Papua Barat', 'Kalimantan Utara', 'Sulawesi Barat',
#        'Kalimantan Barat', 'Kalimantan Selatan',
#        'Kepulauan Bangka Belitung', 'Bengkulu', 'Nusa Tenggara Barat',
#        'Nusa Tenggara Timur', 'Gorontalo'], dtype=object)

# %%
df["Total Urban Villages"] = df["Total Urban Villages"].replace(np.nan, 0);
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21759 entries, 0 to 21758
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  21759 non-null  object
#  1   Province              21117 non-null  object
#  2   Total Cases           21759 non-null  int64
#  3   Total Deaths          21759 non-null  int64
#  4   Total Recovered       21759 non-null  int64
#  5   Island                21117 non-null  object
#  6   Total Districts       21759 non-null  int64
#  7   Total Urban Villages  21759 non-null  float64
#  8   Total Rural Villages  21117 non-null  float64
#  9   Population            21759 non-null  int64
#  10  Case Fatality Rate    21759 non-null  object
#  11  Case Recovered Rate   21759 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# ...

# %%
df["Total Rural Villages"] = df["Total Rural Villages"].replace(np.nan, 0);
df.info()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21759 entries, 0 to 21758
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  21759 non-null  object
#  1   Province              21117 non-null  object
#  2   Total Cases           21759 non-null  int64
#  3   Total Deaths          21759 non-null  int64
#  4   Total Recovered       21759 non-null  int64
#  5   Island                21117 non-null  object
#  6   Total Districts       21759 non-null  int64
# ...

# %%
change the data format "date"

# %%
import datetime
covid["Date"] = covid["Date"].astype('datetime64[ns]');
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21117 entries, 0 to 21757
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  21117 non-null  datetime64[ns]
#  1   Province              21117 non-null  object
#  2   Total Cases           21117 non-null  int64
#  3   Total Deaths          21117 non-null  int64
#  4   Total Recovered       21117 non-null  int64
#  5   Island                21117 non-null  object
#  6   Total Districts       21117 non-null  int64
#  7   Total Urban Villages  21117 non-null  float64
#  8   Total Rural Villages  21117 non-null  float64
#  9   Population            21117 non-null  int64
#  10  Case Fatality Rate    21117 non-null  object
#  11  Case Recovered Rate   21117 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 2.1+ MB
# ...

# %% [markdown]
# # retrieve the dataset in 2020

# %%
c = covid[(covid['Date'] >= '2020-01-01') & (covid['Date'] <= '2020-12-31')]
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9713 entries, 0 to 10017
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  9713 non-null   datetime64[ns]
#  1   Province              9713 non-null   object
#  2   Total Cases           9713 non-null   int64
#  3   Total Deaths          9713 non-null   int64
#  4   Total Recovered       9713 non-null   int64
#  5   Island                9713 non-null   object
#  6   Total Districts       9713 non-null   int64
#  7   Total Urban Villages  9713 non-null   float64
#  8   Total Rural Villages  9713 non-null   float64
#  9   Population            9713 non-null   int64
#  10  Case Fatality Rate    9713 non-null   object
#  11  Case Recovered Rate   9713 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 986.5+ KB

# %%
# from google.colab import files
# c.to_csv('cvd.csv', index=True)
# files.download('cvd.csv')

# %% [markdown]
# ## Changing the writing of the province name to match the covid dataset so that it can be combined

# %%
c["Province"]=c["Province"].replace(['Daerah Istimewa Yogyakarta','Kepulauan Bangka Belitung','Kepulauan Riau'],['DI Yogyakarta','Kep. Bangka Belitung','Kep. Riau'])
c
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             Date           Province  Total Cases  Total Deaths  \
# 0     2020-03-01        DKI Jakarta           39            20
# 1     2020-03-02        DKI Jakarta           41            20
# 3     2020-03-02               Riau            2             0
# 4     2020-03-03        DKI Jakarta           43            20
# 6     2020-03-03         Jawa Barat            1             1
# ...          ...                ...          ...           ...
# 10013 2020-12-31  Sulawesi Tenggara         7907           147
# 10014 2020-12-31     Sulawesi Utara         9670           310
# ...

# %% [markdown]
# ## grouping datasets by province and taking the total value of each variable

# %%
cb=c.groupby(["Province"])
covid_data=cb[["Island","Total Cases","Total Deaths","Total Recovered","Population","Total Districts","Total Urban Villages","Total Rural Villages","Case Fatality Rate","Case Recovered Rate"]].max()
covid_data["Date"]="2020"
covid_data
# Out:
#                              Island  Total Cases  Total Deaths  \
# Province
# Aceh                       Sumatera         8746           358
# Bali                  Nusa Tenggara        17593           516
# Banten                         Jawa        18154           525
# Bengkulu                   Sumatera         3603           112
# DI Yogyakarta                  Jawa        12155           259
# DKI Jakarta                    Jawa       183734          3270
# Gorontalo                  Sulawesi         3841           104
# Jambi                      Sumatera         3227            56
# Jawa Barat                     Jawa        90216          1446
# Jawa Tengah                    Jawa        82546          3627
# Jawa Timur                     Jawa        84410          6399
# Kalimantan Barat         Kalimantan         3118            27
# Kalimantan Selatan       Kalimantan        15303           584
# Kalimantan Tengah        Kalimantan         9740           199
# ...

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, Aceh to Sumatera Utara
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Island                34 non-null     object
#  1   Total Cases           34 non-null     int64
#  2   Total Deaths          34 non-null     int64
#  3   Total Recovered       34 non-null     int64
#  4   Population            34 non-null     int64
#  5   Total Districts       34 non-null     int64
#  6   Total Urban Villages  34 non-null     float64
#  7   Total Rural Villages  34 non-null     float64
#  8   Case Fatality Rate    34 non-null     object
#  9   Case Recovered Rate   34 non-null     object
#  10  Date                  34 non-null     object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 4.2+ KB

# %%
# from google.colab import files
# x.to_csv('Covid2020.csv', index=True)
# files.download('Covid2020.csv')

# %%
data2 = pd.read_csv('/content/drive/MyDrive/gigih 2.0/unemployment rate - Sheet1.csv')
data2.head(2)
# Out:
#   PROVINSI  Year  Unemployment Rate (%)  Laki-Laki  Perempuan
# 0     Aceh  2016                   7.57       7.05       8.44
# 1     Bali  2016                   1.89       2.17       1.55

# %% [markdown]
# # retrieve the dataset in 2020 and some columns that will be used for the dashboard

# %%
d2=data2[data2["Year"]== 2020]
d2.columns=['Province','Year','Unemployment Rate (%)', 'Male','Female']
d2
# Out:
#                  Province  Year  Unemployment Rate (%)   Male  Female
# 140                  Aceh  2020                   6.59   6.06    7.47
# 141                  Bali  2020                   5.63   6.73    4.31
# 142                Banten  2020                  10.64  10.60   10.71
# 143              Bengkulu  2020                   4.07   4.10    4.03
# 144         Di Yogyakarta  2020                   4.57   5.37    3.64
# 145           Dki Jakarta  2020                  10.95  11.06   10.76
# 146             Gorontalo  2020                   4.28   4.53    3.86
# 147             Indonesia  2020                   7.07   8.98    6.46
# 148                 Jambi  2020                   5.13   4.44    6.34
# 149            Jawa Barat  2020                  10.46  10.91    9.67
# 150           Jawa Tengah  2020                   6.48   7.13    5.57
# 151            Jawa Timur  2020                   5.84   6.48    4.92
# ...

# %% [markdown]
# ## choose other than row "indonesia" from the dataset

# %%
unemployment = d2[d2['Province'] != 'Indonesia']
unemployment
# Out:
#                  Province  Year  Unemployment Rate (%)   Male  Female
# 140                  Aceh  2020                   6.59   6.06    7.47
# 141                  Bali  2020                   5.63   6.73    4.31
# 142                Banten  2020                  10.64  10.60   10.71
# 143              Bengkulu  2020                   4.07   4.10    4.03
# 144         DI Yogyakarta  2020                   4.57   5.37    3.64
# 145           DKI Jakarta  2020                  10.95  11.06   10.76
# 146             Gorontalo  2020                   4.28   4.53    3.86
# 148                 Jambi  2020                   5.13   4.44    6.34
# 149            Jawa Barat  2020                  10.46  10.91    9.67
# 150           Jawa Tengah  2020                   6.48   7.13    5.57
# 151            Jawa Timur  2020                   5.84   6.48    4.92
# 152      Kalimantan Barat  2020                   5.81   6.17    5.22
# ...

# %% [markdown]
# ## Changing the writing of the province name to match the covid dataset so that it can be combined

# %%
unemployment["Province"]=unemployment["Province"].replace(['Dki Jakarta','Di Yogyakarta'],['DKI Jakarta','DI Yogyakarta'])
unemployment
# Out:
#                  Province  Year  Unemployment Rate (%)   Male  Female
# 140                  Aceh  2020                   6.59   6.06    7.47
# 141                  Bali  2020                   5.63   6.73    4.31
# 142                Banten  2020                  10.64  10.60   10.71
# 143              Bengkulu  2020                   4.07   4.10    4.03
# 144         DI Yogyakarta  2020                   4.57   5.37    3.64
# 145           DKI Jakarta  2020                  10.95  11.06   10.76
# 146             Gorontalo  2020                   4.28   4.53    3.86
# 148                 Jambi  2020                   5.13   4.44    6.34
# 149            Jawa Barat  2020                  10.46  10.91    9.67
# 150           Jawa Tengah  2020                   6.48   7.13    5.57
# 151            Jawa Timur  2020                   5.84   6.48    4.92
# 152      Kalimantan Barat  2020                   5.81   6.17    5.22
# ...

# %%
unemployment.shape
unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 140 to 174
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Province               34 non-null     object
#  1   Year                   34 non-null     int64
#  2   Unemployment Rate (%)  34 non-null     float64
#  3   Male                   34 non-null     float64
#  4   Female                 34 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.6+ KB

# %% [markdown]
# ## combine the covid dataset and the unemployment dataset into one dataset using inner join

# %%
##inner join data covid and data employment
merge=pd.merge(covid_data, unemployment, on='Province', how='inner')
#merge.shape
merge
# Out:
#                 Province         Island  Total Cases  Total Deaths  \
# 0                   Aceh       Sumatera         8746           358
# 1                   Bali  Nusa Tenggara        17593           516
# 2                 Banten           Jawa        18154           525
# 3               Bengkulu       Sumatera         3603           112
# 4          DI Yogyakarta           Jawa        12155           259
# 5            DKI Jakarta           Jawa       183734          3270
# 6              Gorontalo       Sulawesi         3841           104
# 7                  Jambi       Sumatera         3227            56
# 8             Jawa Barat           Jawa        90216          1446
# 9            Jawa Tengah           Jawa        82546          3627
# 10            Jawa Timur           Jawa        84410          6399
# 11      Kalimantan Barat     Kalimantan         3118            27
# 12    Kalimantan Selatan     Kalimantan        15303           584
# ...

# %%
#merge.drop('Date', inplace=True, axis=1)
merge
# Out:
#                 Province         Island  Total Cases  Total Deaths  \
# 0                   Aceh       Sumatera         8746           358
# 1                   Bali  Nusa Tenggara        17593           516
# 2                 Banten           Jawa        18154           525
# 3               Bengkulu       Sumatera         3603           112
# 4          DI Yogyakarta           Jawa        12155           259
# 5            DKI Jakarta           Jawa       183734          3270
# 6              Gorontalo       Sulawesi         3841           104
# 7                  Jambi       Sumatera         3227            56
# 8             Jawa Barat           Jawa        90216          1446
# 9            Jawa Tengah           Jawa        82546          3627
# 10            Jawa Timur           Jawa        84410          6399
# 11      Kalimantan Barat     Kalimantan         3118            27
# 12    Kalimantan Selatan     Kalimantan        15303           584
# ...

# %%
# from google.colab import files
# merge.to_csv('Covid-Unemployment2020.csv', index=True)
# files.download('Covid-Unemployment2020.csv')
